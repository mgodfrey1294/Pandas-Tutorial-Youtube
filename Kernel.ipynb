# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Kernel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# Create DataFrame
my_df = pd.DataFrame(randn(500,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.656552 -0.291435  0.052409  0.952562
# 1    0.767913 -0.841827 -0.112070  0.469517
# 2    0.575235  0.379566  0.513037  0.623122
# 3   -0.616450 -1.293391  0.237253  1.927531
# 4   -2.451869 -1.643418  2.245375 -1.141486
# ..        ...       ...       ...       ...
# 495 -0.611409  1.754480 -0.170020 -0.662527
# 496 -0.106228 -0.246812  0.832689 -0.357828
# 497  0.102390 -1.714316 -0.621948  0.761365
# 498  1.154690  0.020959  0.140444 -0.351147
# 499  0.316213  0.093384 -0.281298 -1.541276
#
# [500 rows x 4 columns]

# %%
# Density and Kernel Density estimation plots with scipy
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# KDE second way to learn shift tab
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Other Method
my_df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
# Change Stuff
my_df['Tues'].plot.kde(alpha=0.4, lw=4)
# Out:
# <Axes: ylabel='Density'>

# %%
# Grid
my_df['Tues'].plot.kde(alpha=0.4, lw=4, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Title
my_df['Tues'].plot.kde(alpha=0.4, lw=4, title='My Awesome KDE Plot')
# Out:
# <Axes: title={'center': 'My Awesome KDE Plot'}, ylabel='Density'>
