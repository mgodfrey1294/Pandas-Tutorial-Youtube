# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Conditional_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Import CSV File
my_df = pd.read_csv('https://raw.githubusercontent.com/flatplanet/Pandas-Youtube-Playlist/main/dog_data.csv')
my_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
# Conditional Selection
# > < = >= <= etc
# Return Booleans
my_df == "BROWN"
# Out:
#       Breed  Color  DogName  OwnerZip
# 0     False   True    False     False
# 1     False  False    False     False
# 2     False  False    False     False
# 3     False  False    False     False
# 4     False  False    False     False
# ...     ...    ...      ...       ...
# 2665  False   True    False     False
# 2666  False  False    False     False
# 2667  False  False    False     False
# 2668  False  False    False     False
# 2669  False  False    False     False
#
# [2670 rows x 4 columns]

# %%
# Return Dataframe with data
my_df[my_df == "BROWN"]
# Out:
#      Breed  Color DogName  OwnerZip
# 0      NaN  BROWN     NaN       NaN
# 1      NaN    NaN     NaN       NaN
# 2      NaN    NaN     NaN       NaN
# 3      NaN    NaN     NaN       NaN
# 4      NaN    NaN     NaN       NaN
# ...    ...    ...     ...       ...
# 2665   NaN  BROWN     NaN       NaN
# 2666   NaN    NaN     NaN       NaN
# 2667   NaN    NaN     NaN       NaN
# 2668   NaN    NaN     NaN       NaN
# 2669   NaN    NaN     NaN       NaN
#
# [2670 rows x 4 columns]

# %%
# Run them on a column
my_df[my_df == "BROWN"]["Color"]
# Out:
# 0       BROWN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 2665    BROWN
# 2666      NaN
# 2667      NaN
# 2668      NaN
# 2669      NaN
# Name: Color, Length: 2670, dtype: object

# %%
# Return Multiple Columns
my_df[my_df == "BROWN"][["Color", "Breed"]]
# Out:
#       Color Breed
# 0     BROWN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ...     ...   ...
# 2665  BROWN   NaN
# 2666    NaN   NaN
# 2667    NaN   NaN
# 2668    NaN   NaN
# 2669    NaN   NaN
#
# [2670 rows x 2 columns]
