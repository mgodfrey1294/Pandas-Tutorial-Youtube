# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Group_By.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Create Data
stuff = {
    'Corporation':['Apple', 'Google', 'Meta', 'Apple', 'Google', 'Meta'],
    'Employees':['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary':[200, 220, 190, 130, 120, 150]
}
# Create Dataframe
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# Group by Corporation - To get the object Locationin memeory
company = my_df.groupby('Corporation')

# %%
# Sum
company.sum(numeric_only = True)
# Out:
#              Salary
# Corporation
# Apple           330
# Google          340
# Meta            340

# %%
# Mean
company.mean(numeric_only = True)
# Out:
#              Salary
# Corporation
# Apple         165.0
# Google        170.0
# Meta          170.0

# %%
# Min Max
company.max()
# Out:
#             Employees  Salary
# Corporation
# Apple            John     200
# Google         Justin     220
# Meta              Wes     190

# %%
# Standard Deviation
company.std(numeric_only = True)
# Out:
#                 Salary
# Corporation
# Apple        49.497475
# Google       70.710678
# Meta         28.284271

# %%
# Variance
company.var(numeric_only = True)
# Out:
#              Salary
# Corporation
# Apple        2450.0
# Google       5000.0
# Meta          800.0

# %%
# Count
company.count()
# Out:
#              Employees  Salary
# Corporation
# Apple                2       2
# Google               2       2
# Meta                 2       2

# %%
# Describe
company.describe()
# Out:
#             Salary
#              count   mean        std    min    25%    50%    75%    max
# Corporation
# Apple          2.0  165.0  49.497475  130.0  147.5  165.0  182.5  200.0
# Google         2.0  170.0  70.710678  120.0  145.0  170.0  195.0  220.0
# Meta           2.0  170.0  28.284271  150.0  160.0  170.0  180.0  190.0
