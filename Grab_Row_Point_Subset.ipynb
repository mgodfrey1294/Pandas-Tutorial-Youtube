# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Grab_Row_Point_Subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# import csv file
my_df = pd.read_csv('https://raw.githubusercontent.com/flatplanet/Pandas-Youtube-Playlist/main/dog_data.csv')
my_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
# Grab Row Method 1 Location
my_df.loc[2]
# Out:
# Breed       BELG MALINOIS
# Color             BRINDLE
# DogName              EICH
# OwnerZip            15238
# Name: 2, dtype: object

# %%
# Grab Row Method 2 Index Location
my_df.iloc[3]
# Out:
# Breed             MIXED
# Color       BLACK/BROWN
# DogName           ARROW
# OwnerZip          15104
# Name: 3, dtype: object

# %%
# Specific Points (row and column)
# my_df.loc['Row', 'COLUMN']
my_df.loc[1, "DogName"]
# Out:
# 'TACODA'

# %%
# Subsets
# my_df.loc[['row', 'row'], ['column', 'column']]
my_df.loc[[1,3], ["DogName","Breed","Color"]]
# Out:
#   DogName         Breed        Color
# 1  TACODA  GER SHEPHERD  BLACK/BROWN
# 3   ARROW         MIXED  BLACK/BROWN
