# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Boxplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# Create DataFrame
my_df = pd.DataFrame(randn(500,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.020008  1.667921 -1.488374 -0.628398
# 1    0.553783 -1.114970 -0.505592  1.039473
# 2    1.693869 -1.589737 -1.921894  0.592473
# 3   -1.563126 -0.826101  0.480487  0.336851
# 4    1.032179 -0.430358  1.284482 -0.952272
# ..        ...       ...       ...       ...
# 495  0.532390 -0.451544 -0.402921  0.777205
# 496  1.884346 -2.069610 -0.543557 -0.279744
# 497 -0.048277  1.029016 -1.167937 -0.707877
# 498  3.030482  0.474864  1.036545 -1.313475
# 499 -2.286771  0.418602  0.012991  2.249129
#
# [500 rows x 4 columns]

# %%
# Boxplots
my_df.plot(kind='box')
# Out:
# <Axes: >

# %%
# Boxplots Size
my_df.plot(kind='box', figsize=(10,5))
# Out:
# <Axes: >

# %%
# Boxplots Color
my_df.plot(kind='box', cmap='jet')
# Out:
# <Axes: >

# %%
# No Legend
my_df.plot(kind='box', legend=True)
# Out:
# <Axes: >

# %%
# Title
my_df.plot(kind='box', title='My Awesome Box Plot')
# Out:
# <Axes: title={'center': 'My Awesome Box Plot'}>

# %%
# Other Way
my_df.plot.box(title='My Awesome Box Plot!')
# Out:
# <Axes: title={'center': 'My Awesome Box Plot!'}>

# %%
# Add Grid
my_df.plot.box(title='My Awesome Box Plot!', grid=True)
# Out:
# <Axes: title={'center': 'My Awesome Box Plot!'}>
