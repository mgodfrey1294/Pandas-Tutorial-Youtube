# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Hex_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# Create DataFrame
my_df = pd.DataFrame(randn(500,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.251817  0.412665  0.245998  1.286542
# 1   -2.161892 -1.364406 -1.237686 -1.532833
# 2   -0.137472 -1.172628  0.560341 -0.577015
# 3    0.295813 -0.121936  1.003449 -0.864764
# 4    1.768955  0.311234  0.191617  2.087187
# ..        ...       ...       ...       ...
# 495  0.033571 -1.684554  0.807576  0.595264
# 496 -0.924099  0.120997 -1.368365  0.939291
# 497  0.429261  0.757069 -0.059990  0.910256
# 498  0.358225 -0.524895 -0.961606 -0.937560
# 499 -1.090121  0.564998 -1.990356 -0.213463
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind='hexbin', x='Mon', y='Tues')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots Gridsize
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots Color
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=10, cmap='magma')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Other Method
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=10, title='My Awesome Hex Plot')
# Out:
# <Axes: title={'center': 'My Awesome Hex Plot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Grid
my_df.plot.hexbin(x='Mon', y='Tues', gridsize=10, title='My Awesome Hex Plot', grid=True)
# Out:
# <Axes: title={'center': 'My Awesome Hex Plot'}, xlabel='Mon', ylabel='Tues'>
