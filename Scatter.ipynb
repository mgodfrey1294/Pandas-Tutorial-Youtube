# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# Create DataFrame
my_df = pd.DataFrame(randn(500,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.520294 -0.271868  3.022717  0.702168
# 1   -0.232632 -1.042819 -0.910569  0.700406
# 2   -0.675121 -0.160128  0.090665 -1.893940
# 3   -0.201163 -0.129371  1.324623 -0.405917
# 4    0.943599  1.116026 -0.278370  0.291363
# ..        ...       ...       ...       ...
# 495 -1.116959 -0.982085 -0.097043  1.401747
# 496 -0.588195  1.111903  0.003711 -0.740495
# 497 -1.032560  0.799042 -1.602202 -0.257395
# 498  0.325455 -0.130353 -0.534531  1.324684
# 499  2.527733 -0.663490 -0.728455 -0.200324
#
# [500 rows x 4 columns]

# %%
# Scatter Plot
my_df.plot(kind='scatter', x='Mon', y='Tues', c='Wed')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Colors: https://matplotlib.org/stable/tutorials/colors/colormaps.html
my_df.plot(kind='scatter', x='Mon', y='Tues', c='Wed', cmap='magma')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*200)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.4)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.4, title='My Awesome Scatter Plot')
# Out:
# <Axes: title={'center': 'My Awesome Scatter Plot'}, xlabel='Mon', ylabel='Tues'>
