# %% [markdown]
# <a href="https://colab.research.google.com/github/mgodfrey1294/Pandas-Tutorial-Youtube/blob/main/Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt

# Create DataFrame
my_df = pd.DataFrame(randn(25,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0   0.076246  0.783356 -0.201528 -0.201335
# 1  -1.580824  0.814227  0.211560  0.160107
# 2   1.265294  1.026296  0.782417  0.208842
# 3  -0.568434  0.794465  2.307745 -1.139681
# 4   1.045141 -1.730981 -0.884186 -1.317855
# 5   0.682069 -0.926225  1.885599 -1.183644
# 6   0.406972 -0.158969 -0.723549 -0.032703
# 7  -0.179258  0.611332  0.204600 -0.647403
# 8  -0.272311 -0.882066 -0.010134 -0.096145
# 9   0.917639  0.252721 -1.339740 -0.892031
# 10  0.171585  0.698292 -1.822593 -1.146345
# 11 -0.177838  0.451365  2.123525 -0.172391
# 12  0.699832  0.283184  0.031094  0.937275
# 13 -0.028604 -0.381691 -0.825427  0.277528
# 14  0.202744  1.580210 -0.535358 -1.304243
# 15 -0.081218 -2.202553 -1.962800 -0.507627
# 16 -0.740982 -2.350388 -0.692474  1.064594
# 17 -0.166135  0.310238  0.897390 -3.196485
# 18 -0.341786 -0.258000  0.949242 -1.130825
# 19 -0.134527 -0.723710  0.091124 -0.327379
# 20 -0.704563 -2.412655  1.220425 -1.400830
# ...

# %%
# Line Plot
my_df.plot(kind='line')
# Out:
# <Axes: >

# %%
# Line plot absolute
my_df.abs().plot(kind='line')
# Out:
# <Axes: >

# %%
# Line Width
my_df.abs().plot(kind='line', lw=5)
# Out:
# <Axes: >

# %%
# Line Single
my_df['Mon'].abs().plot(kind='line')
# Out:
# <Axes: >

# %%
# Line More than one
my_df[['Mon','Tues']].abs().plot(kind='line')
# Out:
# <Axes: >

# %%
# Size
my_df[['Mon','Tues']].abs().plot(kind='line',figsize=(10,5))
# Out:
# <Axes: >

# %%
# Title
my_df[['Mon','Tues']].abs().plot(kind='line', title='My Awesome Line Chart')
# Out:
# <Axes: title={'center': 'My Awesome Line Chart'}>

# %%
# Shading
my_df[['Mon','Tues']].abs().plot(kind='line', alpha=0.3)
# Out:
# <Axes: >

# %%
# Legend
my_df[['Mon','Tues']].abs().plot(kind='line', legend=False)
# Out:
# <Axes: >

# %%
# Second Way Chart
my_df.plot.line()
# Out:
# <Axes: >
